# %%
import pandas as pd

# %%
data = pd.read_csv('Sampled Data.csv')

# %%
data.columns = data.columns.str.replace(' ', '_')

# %%
data.head()
# Out:
#    Year  Year_Text  Month  Month_Text  Day  Day_Text  Hour  Hour_Text  Minute  \
# 0  2020       2020      1           1    1         1     0          0       0
# 1  2020       2020      1           1    1         1     1          1       0
# 2  2020       2020      1           1    1         1     2          2       0
# 3  2020       2020      1           1    1         1     3          3       0
# 4  2020       2020      1           1    1         1     4          4       0
#
#    Minute_Text  ...  Temperature  Dew_Point  DHI  DNI  GHI  Relative_Humidity  \
# 0            0  ...          7.0       -4.9    0    0    0              42.61
# 1            0  ...          6.5       -4.8    0    0    0              44.18
# 2            0  ...          6.0       -4.8    0    0    0              45.80
# 3            0  ...          5.2       -4.8    0    0    0              48.51
# 4            0  ...          4.9       -4.7    0    0    0              49.70
#
# ...

# %%
import matplotlib as mp

# %%
hour0 = data[data.Hour == 0]
hour1 = data[data.Hour == 1]
hour2 = data[data.Hour == 2]
hour3 = data[data.Hour == 3]
hour4 = data[data.Hour == 4]
hour5 = data[data.Hour == 5]
hour6 = data[data.Hour == 6]
hour7 = data[data.Hour == 7]
hour8 = data[data.Hour == 8]
hour9 = data[data.Hour == 9]
hour10 = data[data.Hour == 10]
hour11 = data[data.Hour == 11]
hour12 = data[data.Hour == 12]
hour13 = data[data.Hour == 13]
hour14 = data[data.Hour == 14]
hour15 = data[data.Hour == 15]
hour16 = data[data.Hour == 16]
hour17 = data[data.Hour == 17]
hour18 = data[data.Hour == 18]
hour19 = data[data.Hour == 19]
hour20 = data[data.Hour == 20]
hour21 = data[data.Hour == 21]
hour22 = data[data.Hour == 22]
hour23 = data[data.Hour == 23]

# %%
hour0.DHI.plot(xlabel = 'Hour 0', ylabel = 'DHI')
# Out:
# <AxesSubplot:xlabel='Hour 0', ylabel='DHI'>

# %%
hour1.DHI.plot(xlabel = 'Hour 1', ylabel = 'DHI')
# Out:
# <AxesSubplot:xlabel='Hour 1', ylabel='DHI'>

# %%
hour2.DHI.plot(xlabel = 'Hour 2', ylabel = 'DHI')
# Out:
# <AxesSubplot:xlabel='Hour 2', ylabel='DHI'>

# %%
hour3.DHI.plot(xlabel = 'Hour 3', ylabel = 'DHI')
# Out:
# <AxesSubplot:xlabel='Hour 3', ylabel='DHI'>

# %%
hour4.DHI.plot(xlabel = 'Hour 4', ylabel = 'DHI')
# Out:
# <AxesSubplot:xlabel='Hour 4', ylabel='DHI'>

# %%
hour21.DHI.plot(xlabel = 'Hour 21', ylabel = 'DHI')
# Out:
# <AxesSubplot:xlabel='Hour 21', ylabel='DHI'>

# %%
hour20.DHI.plot(xlabel = 'Hour 20', ylabel = 'DHI')
# Out:
# <AxesSubplot:xlabel='Hour 20', ylabel='DHI'>

# %%
hour19.DHI.plot(xlabel = 'Hour 19', ylabel = 'DHI')
# Out:
# <AxesSubplot:xlabel='Hour 19', ylabel='DHI'>

# %%
hour18.DHI.plot(xlabel = 'Hour 18', ylabel = 'DHI')
# Out:
# <AxesSubplot:xlabel='Hour 18', ylabel='DHI'>

# %%
hour17.DHI.plot(xlabel = 'Hour 17', ylabel = 'DHI')
# Out:
# <AxesSubplot:xlabel='Hour 17', ylabel='DHI'>

# %%
hour16.DHI.plot(xlabel = 'Hour 16', ylabel = 'DHI')
# Out:
# <AxesSubplot:xlabel='Hour 16', ylabel='DHI'>

# %%
hour15.DHI.plot(xlabel = 'Hour 15', ylabel = 'DHI')
# Out:
# <AxesSubplot:xlabel='Hour 15', ylabel='DHI'>

# %%
hour14.DHI.plot(xlabel = 'Hour 14', ylabel = 'DHI')
# Out:
# <AxesSubplot:xlabel='Hour 14', ylabel='DHI'>

# %%
hour13.DHI.plot(xlabel = 'Hour 13', ylabel = 'DHI')
# Out:
# <AxesSubplot:xlabel='Hour 13', ylabel='DHI'>

# %%
hour12.DHI.plot(xlabel = 'Hour 12', ylabel = 'DHI')
# Out:
# <AxesSubplot:xlabel='Hour 12', ylabel='DHI'>

# %%
hour11.DHI.plot(xlabel = 'Hour 11', ylabel = 'DHI')
# Out:
# <AxesSubplot:xlabel='Hour 11', ylabel='DHI'>

# %%
hour10.DHI.plot(xlabel = 'Hour 10', ylabel = 'DHI')
# Out:
# <AxesSubplot:xlabel='Hour 10', ylabel='DHI'>

# %%
hour9.DHI.plot(xlabel = 'Hour 9', ylabel = 'DHI')
# Out:
# <AxesSubplot:xlabel='Hour 9', ylabel='DHI'>

# %%
hour8.DHI.plot(xlabel = 'Hour 8', ylabel = 'DHI')
# Out:
# <AxesSubplot:xlabel='Hour 8', ylabel='DHI'>

# %%
hour7.DHI.plot(xlabel = 'Hour 7', ylabel = 'DHI')
# Out:
# <AxesSubplot:xlabel='Hour 7', ylabel='DHI'>

# %%
hour6.DHI.plot(xlabel = 'Hour 6', ylabel = 'DHI')
# Out:
# <AxesSubplot:xlabel='Hour 6', ylabel='DHI'>

# %%
hour5.DHI.plot(xlabel = 'Hour 5', ylabel = 'DHI')
# Out:
# <AxesSubplot:xlabel='Hour 5', ylabel='DHI'>

# %%
hour22.DHI.plot(xlabel = 'Hour 22', ylabel = 'DHI')
# Out:
# <AxesSubplot:xlabel='Hour 22', ylabel='DHI'>

# %%
hour23.DHI.plot(xlabel = 'Hour 23', ylabel = 'DHI')
# Out:
# <AxesSubplot:xlabel='Hour 23', ylabel='DHI'>
