# %%
import pandas as pd
import matplotlib as mp
import numpy as np

# %%
data = pd.read_csv('Sampled Data.csv')

# %%
data.columns = data.columns.str.replace(' ', '_')

# %%
data.head()
# Out:
#    Year  Year_Text  Month  Month_Text  Day  Day_Text  Hour  Hour_Text  Minute  \
# 0  2020       2020      1           1    1         1     0          0       0
# 1  2020       2020      1           1    1         1     1          1       0
# 2  2020       2020      1           1    1         1     2          2       0
# 3  2020       2020      1           1    1         1     3          3       0
# 4  2020       2020      1           1    1         1     4          4       0
#
#    Minute_Text  ...  Temperature  Dew_Point  DHI  DNI  GHI  Relative_Humidity  \
# 0            0  ...          7.0       -4.9    0    0    0              42.61
# 1            0  ...          6.5       -4.8    0    0    0              44.18
# 2            0  ...          6.0       -4.8    0    0    0              45.80
# 3            0  ...          5.2       -4.8    0    0    0              48.51
# 4            0  ...          4.9       -4.7    0    0    0              49.70
#
# ...

# %%
# The following sets of codes displays the graph of the various parameters of the data.
# The salient feature of them is they almost remain constant throughout the year, with an accuracy of hour.
# These parameters can be used to define the reference keys for the experiment.
# The best among all is Surface Albedo, as it remains constant for a long interval of time
# The X-axis of the plots is the unique id, given to each data point, named as "Time."
# The convention used for naming can be used for any amount of data we have. It will remain unique.
# The unique key is time sorted.

# %%
for i in range(12):
    for j in range(24):
        month = data[data.Month == i]
        hour = data[data.Hour == j]
        hour.Pressure.plot()

# %%
mean = data.Pressure.mean()
variance = data.Pressure.var()
print('Mean - ', mean)
print('Variance - ', variance)
# Out:
# Mean -  984.6293260473589
# Variance -  50.39406644770609

# %%
for i in range(12):
    for j in range(24):
        month = data[data.Month == i]
        hour = data[data.Hour == j]
        hour.Dew_Point.plot()

# %%
mean = data.Dew_Point.mean()
variance = data.Dew_Point.var()
print('Mean - ', mean)
print('Variance - ', variance)
# Out:
# Mean -  12.24261156648451
# Variance -  84.89586934881746

# %%
for i in range(12):
    for j in range(24):
        month = data[data.Month == i]
        hour = data[data.Hour == j]
        hour.Precipitable_Water.plot()

# %%
mean = data.Precipitable_Water.mean()
variance = data.Precipitable_Water.var()
print('Mean - ', mean)
print('Variance - ', variance)
# Out:
# Mean -  2.9271288706739687
# Variance -  3.887039188217924

# %%
for i in range(12):
    for j in range(24):
        month = data[data.Month == i]
        hour = data[data.Hour == j]
        hour.Solar_Zenith_Angle.plot()

# %%
mean = data.Solar_Zenith_Angle.mean()
variance = data.Solar_Zenith_Angle.var()
print('Mean - ', mean)
print('Variance - ', variance)
# Out:
# Mean -  89.76152322404378
# Variance -  1727.6936468654535

# %%
for i in range(24):
    month = data[data.Hour == i]
    month.Solar_Zenith_Angle.plot()

# %%
for i in range(12):
    for j in range(24):
        month = data[data.Month == i]
        hour = data[data.Hour == j]
        hour.Ozone.plot()

# %%
mean = data.Ozone.mean()
variance = data.Ozone.var()
print('Mean - ', mean)
print('Variance - ', variance)
# Out:
# Mean -  0.28034904371584507
# Variance -  0.00037004096914118714

# %%
for i in range(12):
    for j in range(24):
        month = data[data.Month == i]
        hour = data[data.Hour == j]
        hour.Surface_Albedo.plot()

# %%
mean = data.Surface_Albedo.mean()
variance = data.Surface_Albedo.var()
print('Mean - ', mean)
print('Variance - ', variance)
# Out:
# Mean -  0.18819672131151066
# Variance -  0.00017818923665876817

# %%
for i in range(12):
    for j in range(24):
        month = data[data.Month == i]
        hour = data[data.Hour == j]
        hour.Temperature.plot()

# %%
mean = data.Temperature.mean()
variance = data.Temperature.var()
print('Mean - ', mean)
print('Variance - ', variance)
# Out:
# Mean -  25.119114298724988
# Variance -  85.39385183983197
