# %%
# https://simdkalman.readthedocs.io/en/latest/

# %%
import simdkalman

# %%
import numpy as np

# %%
kf = simdkalman.KalmanFilter(
    state_transition = [[1, 1], [0, 1]],
    process_noise = np.diag([0.1, 0.01]),
    observation_model = np.array([[1, 0]]),
    observation_noise = 1.0)

# %%
kf

# %%
import numpy.random as random

# %%
data = random.normal(size = (100, 200))

# %%
data[random.uniform(size = data.shape) < 0.1] = np.nan

# %%
data
# Out:
# array([[ 2.37920007, -1.13287279,         nan, ...,         nan,
#                 nan,         nan],
#        [ 0.66598332,  1.62562881, -0.80119324, ..., -1.0215095 ,
#          0.80346308,  0.1669901 ],
#        [        nan,  0.69438923, -0.63443874, ..., -1.63140693,
#          0.44706784, -0.43786343],
#        ...,
#        [ 1.05763998,  0.4375143 , -0.51810554, ..., -0.58233269,
#         -1.23751215, -0.27953639],
#        [ 0.4385245 ,  2.59502333, -0.51447132, ..., -2.03160024,
#          0.16200312,  0.19887844],
#        [-0.1966889 , -2.6401791 , -1.96880625, ..., -0.42949483,
#         -0.24846797, -0.12241985]])

# %%
smoothed = kf.smooth(data,
                    initial_value = [1, 0], 
                    initial_covariance = np.eye(2) * 0.5)

# %%
print('mean')
print(smoothed.states.mean[1, 2, :])
# Out:
# mean
# [ 0.34998615 -0.09485397]

# %%
print('covariance')
print(smoothed.states.cov[1, 2, :, :])
# Out:
# covariance
# [[ 0.18381972 -0.00725583]
#  [-0.00725583  0.02561241]]

# %%
smoothed

# %%
print(smoothed)
# Out:
# states:
#   mean:
#     [[[ 1.00332381 -0.09040144]
#       [ 0.77599951 -0.07851718]
#       [ 0.7514467  -0.07202936]
#       ...
#       [ 0.55484535  0.12258403]
#       [ 0.67742938  0.12258403]
#       [ 0.80001341  0.12258403]]
#
#      [[ 0.7555146  -0.11256091]
#       [ 0.60300974 -0.11081773]
#       [ 0.34998615 -0.09485397]
#       ...
#       [ 0.14651146 -0.0036595 ]
#       [ 0.20046559 -0.00392811]
#       [ 0.19385135 -0.00392811]]
#
#      [[ 0.7321282  -0.08169576]
#       [ 0.59685808 -0.07797224]
#       [ 0.45555836 -0.06791597]
#       ...
#       [-0.65583863 -0.0479502 ]
#       [-0.58332505 -0.04620775]
#       [-0.61210831 -0.04620775]]
#
#      ...
#
#      [[ 0.62659574 -0.13757782]
#       [ 0.37123264 -0.12855084]
#       [ 0.11826836 -0.10708253]
#       ...
#       [-0.65686139 -0.04583611]
#       [-0.71213331 -0.0415259 ]
#       [-0.71055714 -0.0415259 ]]
#
#      [[ 0.82738547 -0.12316719]
#       [ 0.70858147 -0.12606685]
#       [ 0.39823362 -0.11053842]
#       ...
#       [-0.64717511  0.05783418]
#       [-0.47091723  0.06334735]
#       [-0.35243821  0.06334735]]
#
#      [[-0.16420797 -0.08318698]
#       [-0.47698845 -0.06189137]
#       [-0.55215426 -0.03926831]
#       ...
#       [ 0.23543297 -0.03025194]
#       [ 0.14455277 -0.03238456]
#       [ 0.09084202 -0.03238456]]]
#   cov:
#     [[[[ 0.24136872 -0.03707954]
#        [-0.03707954  0.03662701]]
#
#       [[ 0.21813336 -0.01710891]
#        [-0.01710891  0.03009324]]
#
#       [[ 0.23370276 -0.0088145 ]
#        [-0.0088145   0.02549281]]
#
#       ...
#
#       [[ 0.73356509  0.13092835]
#        [ 0.13092835  0.06604334]]
#
#       [[ 1.16146514  0.19697169]
#        [ 0.19697169  0.07604334]]
#
#       [[ 1.73145185  0.27301503]
#        [ 0.27301503  0.08604334]]]
#
#
#      [[[ 0.22610708 -0.03793924]
#        [-0.03793924  0.03672042]]
#
#       [[ 0.19019938 -0.0175326 ]
#        [-0.0175326   0.0302293 ]]
#
#       [[ 0.18381972 -0.00725583]
#        [-0.00725583  0.02561241]]
#
#       ...
#
#       [[ 0.22536372  0.01302896]
#        [ 0.01302896  0.03776753]]
#
#       [[ 0.28196577  0.03692488]
#        [ 0.03692488  0.04631181]]
#
#       [[ 0.42324574  0.07566972]
#        [ 0.07566972  0.05631181]]]
#
#
#      [[[ 0.29142875 -0.0495149 ]
#        [-0.0495149   0.03842763]]
#
#       [[ 0.21924928 -0.02541404]
#        [-0.02541404  0.03171689]]
#
#       [[ 0.1923091  -0.01240629]
#        [-0.01240629  0.02679069]]
#
#       ...
#
#       [[ 0.21796544  0.01475762]
#        [ 0.01475762  0.03729159]]
#
#       [[ 0.27868508  0.03803328]
#        [ 0.03803328  0.04582471]]
#
#       [[ 0.42196393  0.07623454]
#        [ 0.07623454  0.05582471]]]
#
#
#      ...
#
#
#      [[[ 0.22565685 -0.03829767]
#        [-0.03829767  0.03660836]]
#
#       [[ 0.1883945  -0.01809387]
#        [-0.01809387  0.03013425]]
#
#       [[ 0.17943132 -0.00797104]
#        [-0.00797104  0.0255648 ]]
#
#       ...
#
#       [[ 0.24710882  0.01513141]
#        [ 0.01513141  0.0369207 ]]
#
#       [[ 0.29952548  0.03787577]
#        [ 0.03787577  0.04546161]]
#
#       [[ 0.43862696  0.07576125]
#        [ 0.07576125  0.05546161]]]
#
#
#      [[[ 0.22570045 -0.03833986]
#        [-0.03833986  0.0364236 ]]
#
#       [[ 0.18817372 -0.0183387 ]
#        [-0.0183387   0.02994465]]
#
#       [[ 0.17842281 -0.00844678]
#        [-0.00844678  0.02537821]]
#
#       ...
#
#       [[ 0.21968582  0.0143527 ]
#        [ 0.0143527   0.0372391 ]]
#
#       [[ 0.27934881  0.03765035]
#        [ 0.03765035  0.04578   ]]
#
#       [[ 0.42184257  0.07584578]
#        [ 0.07584578  0.05578   ]]]
#
#
#      [[[ 0.22570114 -0.03830944]
#        [-0.03830944  0.0363722 ]]
#
#       [[ 0.18820258 -0.01835174]
#        [-0.01835174  0.0298893 ]]
#
#       [[ 0.17841306 -0.00851252]
#        [-0.00851252  0.02531722]]
#
#       ...
#
#       [[ 0.21698852  0.01531595]
#        [ 0.01531595  0.03697465]]
#
#       [[ 0.27852745  0.03825948]
#        [ 0.03825948  0.04550939]]
#
#       [[ 0.42194695  0.07615352]
#        [ 0.07615352  0.05550939]]]]
# observations:
#   mean:
#     [[ 1.00332381  0.77599951  0.7514467  ...  0.55484535  0.67742938
#        0.80001341]
#      [ 0.7555146   0.60300974  0.34998615 ...  0.14651146  0.20046559
#        0.19385135]
#      [ 0.7321282   0.59685808  0.45555836 ... -0.65583863 -0.58332505
#       -0.61210831]
#      ...
#      [ 0.62659574  0.37123264  0.11826836 ... -0.65686139 -0.71213331
#       -0.71055714]
#      [ 0.82738547  0.70858147  0.39823362 ... -0.64717511 -0.47091723
#       -0.35243821]
#      [-0.16420797 -0.47698845 -0.55215426 ...  0.23543297  0.14455277
#        0.09084202]]
#   cov:
#     [[1.24136872 1.21813336 1.23370276 ... 1.73356509 2.16146514 2.73145185]
#      [1.22610708 1.19019938 1.18381972 ... 1.22536372 1.28196577 1.42324574]
#      [1.29142875 1.21924928 1.1923091  ... 1.21796544 1.27868508 1.42196393]
#      ...
#      [1.22565685 1.1883945  1.17943132 ... 1.24710882 1.29952548 1.43862696]
#      [1.22570045 1.18817372 1.17842281 ... 1.21968582 1.27934881 1.42184257]
#      [1.22570114 1.18820258 1.17841306 ... 1.21698852 1.27852745 1.42194695]]

# %%
print(kf)
# Out:
# <simdkalman.kalmanfilter.KalmanFilter object at 0x000001D809F147C0>

# %%
predicted = kf.predict(data[1, :], 123)

# %%
pred_mean = predicted.observations.mean[2]

# %%
pred_stdev = np.sqrt(predicted.observations.cov[2])

# %%
print('%g +- %g' % (pred_mean, pred_stdev))
# Out:
# 0.182067 +- 1.6535
