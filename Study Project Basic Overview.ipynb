# %%
import pandas as pd

# %%
data = pd.read_csv("Sampled Data.csv")

# %%
import matplotlib as mp

# %%
data.columns = data.columns.str.replace(' ', '_')

# %%
data.head()
# Out:
#    Year  Year_Text  Month  Month_Text  Day  Day_Text  Hour  Hour_Text  Minute  \
# 0  2020       2020      1           1    1         1     0          0       0
# 1  2020       2020      1           1    1         1     1          1       0
# 2  2020       2020      1           1    1         1     2          2       0
# 3  2020       2020      1           1    1         1     3          3       0
# 4  2020       2020      1           1    1         1     4          4       0
#
#    Minute_Text  ...  Temperature  Dew_Point  DHI  DNI  GHI  Relative_Humidity  \
# 0            0  ...          7.0       -4.9    0    0    0              42.61
# 1            0  ...          6.5       -4.8    0    0    0              44.18
# 2            0  ...          6.0       -4.8    0    0    0              45.80
# 3            0  ...          5.2       -4.8    0    0    0              48.51
# 4            0  ...          4.9       -4.7    0    0    0              49.70
#
# ...

# %%
data.plot(x = 'Time', y = 'Clearsky_DHI', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Clearsky_DNI', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Clearsky_GHI', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Cloud_Type', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Fill_Flag', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Ozone', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Solar_Zenith_Angle', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Precipitable_Water', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Temperature', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Dew_Point', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'DHI', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'GHI', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Relative_Humidity', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Surface_Albedo', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Pressure', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Wind_Direction', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Wind_Speed', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Clearsky_DHI', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Clearsky_DHI'>
